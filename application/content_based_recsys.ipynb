# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
def get_playlist_vector(feature_set, playlist_df):
    '''
    Summarize a user's playlist into a vector.
    '''
    feature_set_playlist = feature_set[feature_set['id'].isin(playlist_df)]
    feature_set_playlist.drop(columns='id', inplace=True)
    playlist_vector = feature_set_playlist.sum()

    feature_set_nonplaylist = feature_set[~feature_set['id'].isin(playlist_df)]

    return playlist_vector, feature_set_nonplaylist

# %%
def get_recommendations(tracks, playlist_vector, feature_set_nonplaylist, n=10):
    '''
    Generate music recommendations.
    '''
    nonplaylist_tracks = tracks[tracks['id'].isin(
        feature_set_nonplaylist['id'].values)]

    # calculate cosine similarity between the playlist and each non-playlist track
    nonplaylist_tracks['similarity'] = cosine_similarity(feature_set_nonplaylist.drop(
        'id', axis=1).values, playlist_vector.values.reshape(1, -1))[:, 0]

    return nonplaylist_tracks.sort_values('similarity', ascending=False).head(n)

# %%
tracks = pd.read_csv('../data/tracks.csv')
feature_set = pd.read_csv('../data/feature_set.csv')
playlist_df = pd.read_csv('../data/test_playlist.csv')

playlist_vector, feature_set_nonplaylist = get_playlist_vector(
    feature_set, playlist_df)

get_recommendations(tracks, playlist_vector, feature_set_nonplaylist)
# Out:
# /var/folders/vy/c6j5yw3x6td0lcrhv8v891900000gn/T/ipykernel_9767/3472052492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   feature_set_playlist.drop(columns='id', inplace=True)
#                artist_name                      id  \
# 0            Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 22954           Kanye West  1o0kWPueYo94LIjPYOE5Nf
# 22968                Usher  2RFX8hjyXcoHHOA1TT0wd6
# 22967                Usher  30h7zzirGFFek9IGtU4TQs
# 22966  Natasha Bedingfield  4cA2o1upk9WESyVgmz3n3Q
# 22965          Gorilla Zoe  7ytLGF9Ua5g5MylbwtxzZC
# 22964         Trevor Moran  22YAYDyBi4tBN6MsJbB9kw
# 22963            Deliri0us  4qNWKwI6XfaURVwwyktRfL
# 22962        Chasin' Crazy  6FxDXvbEraNGZDTYqKyKft
# 22961       Ruthie Collins  7obLTRZEzqYc5LQkNIl6Rg
#
#                                        track_name  danceability  energy  key  \
# 0      Lose Control (feat. Ciara & Fat Man Scoop)         0.904   0.813    4
# 22954                                 Saint Pablo         0.461   0.772    2
# 22968                                   Lil Freak         0.834   0.628    7
# 22967                                        Numb         0.577   0.687    8
# 22966                                 Wild Horses         0.407   0.229    9
# 22965               Echo - Explicit Album Version         0.809   0.744    0
# 22964                                        Echo         0.775   0.852    6
# 22963                     Delirious Outta My Mind         0.785   0.807   11
# 22962                                   Smack Dab         0.634   0.870    5
# 22961                                Ramblin' Man         0.625   0.715    6
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -7.105     0       0.1210      0.031100          0.006970    0.0471
# 22954    -3.980     0       0.3750      0.282000          0.000000    0.1780
# 22968    -6.616     1       0.0626      0.000879          0.000192    0.2920
# 22967    -7.601     1       0.0471      0.011300          0.000004    0.1120
# 22966    -9.801     0       0.0326      0.867000          0.000000    0.0797
# 22965    -5.892     0       0.0434      0.080900          0.000000    0.2100
# 22964    -3.876     0       0.0911      0.188000          0.000001    0.0566
# 22963    -5.333     0       0.2850      0.650000          0.000000    0.1010
# 22962    -4.523     1       0.0375      0.007090          0.000000    0.4140
# 22961    -5.407     1       0.0329      0.228000          0.000029    0.2050
#
#        valence    tempo  artist_popularity  \
# 0        0.810  125.461                 74
# 22954    0.414  167.018                 94
# 22968    0.766  139.958                 82
# 22967    0.291  124.956                 82
# 22966    0.308  133.891                 69
# 22965    0.572  107.990                 55
# 22964    0.530   99.037                 36
# 22963    0.697   96.034                 23
# 22962    0.880  119.996                 15
# 22961    0.840  122.978                 28
#
#                                                   genres  track_popularity  \
# 0      ['dance_pop', 'hip_hop', 'hip_pop', 'pop', 'po...                69
# 22954                             ['chicago_rap', 'rap']                69
# 22968  ['atl_hip_hop', 'contemporary_r&b', 'dance_pop...                 0
# 22967  ['atl_hip_hop', 'contemporary_r&b', 'dance_pop...                 0
# 22966  ['dance_pop', 'europop', 'neo_mellow', 'pop', ...                 3
# 22965  ['atl_hip_hop', 'crunk', 'dirty_south_rap', 'f...                55
# 22964                                       ['teen_pop']                32
# 22963                                        ['unknown']                37
# 22962                                        ['unknown']                27
# 22961                                    ['country_pop']                18
#
#       subjectivity  polarity  similarity
# 0              low   neutral         0.0
# 22954          low   neutral         0.0
# 22968          low   neutral         0.0
# 22967         high  negative         0.0
# 22966         high  positive         0.0
# 22965          low   neutral         0.0
# 22964          low   neutral         0.0
# 22963          low   neutral         0.0
# 22962          low   neutral         0.0
# 22961          low   neutral         0.0
